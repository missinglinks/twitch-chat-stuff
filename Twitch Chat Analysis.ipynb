# %%
from twitchchat import TwitchChat, timestamp

# %% [markdown]
# #### load chat data

# %%
# data/169687983.json #enb
# data/58724950.json #oro

# %%
chat = TwitchChat("data/58724950.json")

# %% [markdown]
# #### commenter statistics

# %%
len(chat.comments)
# Out:
# 3065

# %%
len(chat.commenters())
# Out:
# 570

# %%
chat.commenters().most_common(10)
# Out:
# [('VagabondHann', 93),
#  ('Delta125', 82),
#  ('everyzig', 79),
#  ('krit_krat', 72),
#  ('NoxTerminus', 67),
#  ('Nohorse', 55),
#  ('BenzieDog', 47),
#  ('BootyBandit', 47),
#  ('ryang1997', 35),
#  ('Moobot', 34)]

# %%
chat.emoticons(info="label").most_common(10)
# Out:
# [('Kappa', 125),
#  ('PogChamp', 70),
#  ('PJSalt', 50),
#  ('Kreygasm', 36),
#  ('KappaPride', 30),
#  ('HeyGuys', 28),
#  ('oroRIP', 20),
#  ('oroHug', 19),
#  ('BabyRage', 19),
#  ('oroShoot', 15)]

# %% [markdown]
# #### messages and emoticons per minute plots

# %%
chat.plot_messages(0,7000,200, text_filter="praise")

# %%
chat.plot_emoticons(0,7000,200)

# %% [markdown]
# #### chat logs

# %%
for x in chat[6600:6800]:
    print(x)

# %% [markdown]
# #### emoticon statistics

# %%
chat.emoticons(info="label").most_common(20)
# Out:
# [('enbPraise', 292),
#  ('Kappa', 242),
#  ('PogChamp', 214),
#  (':D', 131),
#  ('Kreygasm', 109),
#  ('enbClap', 102),
#  ('enbKiss', 94),
#  ('VoHiYo', 82),
#  ('enbHaru', 79),
#  ('enbSup', 70),
#  ('Jebaited', 69),
#  ('TwitchRPG', 60),
#  ('<3', 58),
#  ('enbFalchion', 52),
#  ('enbTrash', 52),
#  ('BibleThump', 51),
#  (':P', 45),
#  ('enbRip', 45),
#  (':)', 43),
#  ('enbLol', 37)]

# %%
chat.emoticons(info="link").most_common(20)
# Out:
# [('https://static-cdn.jtvnw.net/emoticons/v1/111990/3.0', 291),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/25/3.0', 242),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/88/3.0', 214),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/3/3.0', 131),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/41/3.0', 109),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/113378/3.0', 102),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/114712/3.0', 94),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/81274/3.0', 82),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/410082/3.0', 79),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/111769/3.0', 70),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/114836/3.0', 69),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/191747/3.0', 60),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/9/3.0', 57),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/172336/3.0', 52),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/173129/3.0', 52),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/86/3.0', 51),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/12/3.0', 48),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/1/3.0', 45),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/383288/3.0', 45),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/114713/3.0', 37)]

# %%
for c in wapo.comments:
    if "" in c.message.lower():
        print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-a3a45e71549c> in <module>
# ----> 1 for c in wapo.comments:
#       2     if "" in c.message.lower():
#       3         print(c)
#
# NameError: name 'wapo' is not defined

# %%
bob = TwitchChat("data/313061370.json")

# %%
bob.plot_emoticons()

# %%
bob.plot_messages()

# %%
bob.commenters().most_common(30)
# Out:
# [('Tiamat37', 411),
#  ('letangier', 248),
#  ('twltchers', 211),
#  ('Moobot', 192),
#  ('chocosinok', 153),
#  ('Hemi_Dippin', 152),
#  ('nasgdt', 152),
#  ('theGrumpiestUnicorn', 141),
#  ('VaiaSilvers', 132),
#  ('vikatje', 121),
#  ('Eric__Tyler', 116),
#  ('Flappityflappyflap', 110),
#  ('DefStamina88', 109),
#  ('laike_ee_gluv', 103),
#  ('SUPERNlNTENDO', 101),
#  ('alfredmojoluna', 100),
#  ('blindn3ss', 100),
#  ('ricesan', 99),
#  ('Chrisby26', 96),
#  ('a_i_ngelic', 96),
#  ('Swoophy', 95),
#  ('Hizenkai', 90),
#  ('savvygreed', 90),
#  ('peeinmycheerios', 85),
#  ('Ayoken007', 82),
#  ('shrimpbeast', 82),
#  ('AJohnB', 80),
#  ('quarkstrudl', 80),
#  ('ccarnage86', 79),
#  ('MillaMallowBunny', 78)]

# %%
for c in bob.comments:
    if "trump" in c.message.lower():
        print(c)
# Out:
# 0:53:33.54         [yellowfreeze2014] - donald trumps hair
# 3:58:18.73         [newrubric] - Trump cloud
# 7:26:44.60         [jeremyracerperrin69] - Robert Bellow plays his cats like. Trumpet!
# 7:28:10.77         [jeremyracerperrin69] - Can bob paint a cat being played like a trumpet???
# 7:34:25.06         [jeremyracerperrin69] - Robert is playing his cat like a trumpet...Robert Bellow..
# 11:54:23.13        [Rapidsnapx] - I'm not a fan of any President or Prime Minster. I'm just a fan of whoever is managing their country better than anyone else in the world, and right now that just happens to be Donald Trump
# 12:02:46.99        [Tarsiz_] - i'm sorry to disappoint but trump has never built a wall with his hands, portuguese are much better at building walls
# 12:37:44.93        [Xayahis] - trump was a little happy accident
# 12:38:16.49        [saucydonut24] - trump just a accident
# 13:23:24.62        [Menjood] - trumpWow
# 20:04:54.80        [yellowfreeze2014] - donald trumps hair?
# 21:12:51.31        [Tiamat37] - usa has trump.... landfill > USA
# 22:08:51.79        [Eric__Tyler] - with this music, I feel like Trumpy is going to start showing up

# %%
for c in bob.comments:
    if c.commenter["name"] == "Tiamat37":
        print(c)

# %%
from twitchchat import TwitchChat, timestamp

# %% [markdown]
# #### load chat data

# %%
# data/169687983.json #enb
# data/58724950.json #oro

# %%
chat = TwitchChat("data/169687983.json")

# %% [markdown]
# #### commenter statistics

# %%
len(chat.comments)
# Out:
# 6967

# %%
len(chat.commenters())
# Out:
# 675

# %%
chat.commenters().most_common(10)
# Out:
# [('viiranen', 390),
#  ('portablejerkops', 267),
#  ('TerrorOfDeth', 190),
#  ('tenro007', 189),
#  ('Moobot', 163),
#  ('dyford9', 160),
#  ('DarkSoulSama', 128),
#  ('mammamia_senorita', 122),
#  ('M3SSR', 122),
#  ('gogosox82', 119)]

# %%
chat.emoticons(info="label").most_common(10)
# Out:
# [('enbPraise', 292),
#  ('Kappa', 242),
#  ('PogChamp', 214),
#  (':D', 131),
#  ('Kreygasm', 109),
#  ('enbClap', 102),
#  ('enbKiss', 94),
#  ('VoHiYo', 82),
#  ('enbHaru', 79),
#  ('enbSup', 70)]

# %% [markdown]
# #### messages and emoticons per minute plots

# %%
chat.plot_messages(0,7000,200)

# %%
chat.plot_emoticons(0,7000,200, emote_filter="enbPraise")

# %%
for x in chat[1600:1800]:
    print(x)
# Out:
# 0:26:44.67         [Nohorse] - Duel talismans renamed "Dishonor talisman" in latest patch, confirmed SeemsGood
# 0:26:52.25         [BenzieDog] - Peeb stop whining please
# 0:26:53.53         [ScifiSaint] - BabyRage
# 0:26:55.42         [Hot_doggity] - Did oro lose left?
# 0:26:56.89         [PsYkiiiK] - wheres EGWT when u need him
# 0:27:03.56         [3eetle] - as he says with his 1k deeps combo Kappa
# 0:27:09.16         [2ezrqoN] - in dks1 i'd just ringswap to dwgr and flip around people until their buff wore off
# 0:27:10.76         [Hot_doggity] - Yet****
# 0:27:10.79         [ds4calvin] - Rant Ranterson Kappa
# 0:27:13.19         [illuminati_reptile_] - how about no talismans but have to buff mid duel?
# 0:27:13.65         [TheChief1114] - Hey guys
# 0:27:14.73         [ryang1997] - lol
# 0:27:14.82         [3eetle] - but buffs aint ok Kappa
# 0:27:17.32         [Lovage] - PJSalt
# 0:27:18.93         [Reddles] - At least it's better than the FUGS.
# ...

# %%
chat.plot_messages(74000,76000, 100)

# %%
chat.plot_emoticons(74000,76000, 100)

# %%
for x in chat[74100:74600]:
    print(x)
# Out:
# 20:35:01.83        [Airbomb24] - Forks Hound
# 20:35:03.64        [BigEl_nobody] - @Clementeblue of course he likes it more .... its the way MGS was meant to be played (tm) Kappa
# 20:35:09.98        [Turtlezzzz] - can we get a funny outfit cutscene
# 20:35:13.83        [Peace_Duster] - Clementeblue I'm 7 fott tall electric bisexual Russian, I'll destroy you ohnRaiden
# 20:35:31.35        [obese_juan_kenobi] - grey fox in the original VO was waaaaaaaay better! you can hear the pain in his voice
# 20:35:32.20        [PixelCrit] - Where is the duck outfit?
# 20:35:34.63        [blagdenlecorbeau] - what is he doing ?
# 20:35:40.48        [feefer_drunkerland] - @Clementeblue i am also bisexual russian prepare to die ohnRaiden
# 20:35:41.19        [Clementeblue] - @Peace_Duster oh god... i'm a manlet compared to you... please forgive me Monka
# 20:35:41.52        [SeknAnkeS] - stabbing her
# 20:35:46.61        [blagdenlecorbeau] - But why
# ...

# %%
chat.plot_messages(26000, 29000, 100)

# %%
chat.plot_emoticons(26000, 29000, 100)

# %%
for x in chat[27800:28200]:
    print(x)
# Out:
# 7:43:20.77         [WingZer0_G] - Locked and ohnDUDDERS 'ed
# 7:43:22.19         [Sir_Magneto] - ohnDud
# 7:43:23.45         [7r1cks7a] - ohnYell Hooooold!
# 7:43:24.39         [ResidentRogue] - moon2MLADY
# 7:43:25.02         [Hatez_san] - danGachi
# 7:43:25.54         [JSaysNein] - HOLD LADS
# 7:43:25.88         [BigEl_nobody] - I want at least 7k DUD boys ohnYell
# 7:43:26.11         [payucon] - Please dont crash my pc guys
# 7:43:26.17         [RockEnzo] - hold your DUD PogChamp
# 7:43:27.15         [UninstallDota] - Kreygasm
# 7:43:28.88         [kupoTroopa] - awww yissss
# 7:43:29.02         [Kefka_did_nothing_wrong] - Locked and loaded
# 7:43:29.42         [born2killll] - hold the line
# 7:43:31.01         [YunFug] - the moment i've been waiting for ohnDud
# 7:43:32.54         [SecondNaut] - Can't hold all these ohnDuds
# 7:43:36.29         [Yugiberto] - atpGasm atpGasm atpGasm atpGasm atpGasm atpGasm
# 7:43:39.09         [Killa_C12] - ohnDud I'm ohnDud leaking ohnDud
# ...

# %%
mgs3 = TwitchChat("data/315472798.json")

# %%
mgs3.plot_messages()

# %%
mgs3.plot_emoticons()

# %%
mgs3.plot_messages(55000, 57000, 100)

# %%
timestamp(55250)
# Out:
# '15:20:50'

# %%
mgs3.plot_emoticons(55000, 57000, 100)

# %% [markdown]
# #### chat logs

# %%
for x in mgs3[55200:55600]:
    print(x)
# Out:
# 15:20:02.24        [yoursaltygymsocks] - Im ready PogChamp PogChamp PogChamp PogChamp PogChamp
# 15:20:03.50        [Yannik_93] - maxyyParty
# 15:20:06.08        [Xsal1989x] - who's streaming mgs 4? Dogg?
# 15:20:07.40        [ManOf1000Jutsu] - why did he kill the snake i the tree?
# 15:20:11.98        [DaftNathaniel] - moon2PH
# 15:20:13.05        [killjoyz88] - i stopped at 33 hours last
# 15:20:20.54        [yiyo3000094] - Soo many memories
# 15:20:24.34        [killjoyz88] - continuing the show
# 15:20:24.80        [Drakomus] - klinkGun here i come
# 15:20:32.44        [Commandant_mazarin] - Need the snake for food.
# 15:20:35.54        [ABoyNamedSue] - This part in ps2 was really bad fps
# 15:20:36.62        [greenninjacyborgdudee] - SourPls
# 15:20:38.57        [MajorTeodo] - WHAT A THRILL
# 15:20:39.50        [RhombusOfTerror] - WHAT A THRILL
# 15:20:43.43        [Faux_Paz] - WHAT A THRILL
# 15:20:44.29        [Hoves] - WHAT A THRILL
# ...

# %% [markdown]
# #### emoticon statistics

# %%
chat.emoticons(info="link").most_common(20)
# Out:
# [('https://static-cdn.jtvnw.net/emoticons/v1/46386/3.0', 9604),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/25047/3.0', 4207),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/5670/3.0', 4165),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/425618/3.0', 2391),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/107525/3.0', 2259),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/374284/3.0', 1542),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/11709/3.0', 1539),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/479614/3.0', 1511),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/86/3.0', 1502),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/25/3.0', 1463),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/108006/3.0', 1398),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/88/3.0', 1277),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/165400/3.0', 1023),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/180015/3.0', 958),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/394726/3.0', 886),
# ...

# %%
wapo = TwitchChat("data/315348674.json")

# %%
wapo.plot_messages()

# %%
wapo.plot_emoticons()

# %%
corpus = wapo.message_corpus(5000, 20000)

# %%
corpus.emoticons.most_common(15)
# Out:
# [('https://static-cdn.jtvnw.net/emoticons/v1/425618/3.0', 1012),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/88/3.0', 465),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/86/3.0', 261),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/1/3.0', 212),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/25/3.0', 203),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/354/3.0', 162),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/1290549/3.0', 107),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/28087/3.0', 81),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/33/3.0', 76),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/357/3.0', 68),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/360/3.0', 66),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/245/3.0', 65),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/9/3.0', 63),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/58765/3.0', 56),
#  ('https://static-cdn.jtvnw.net/emoticons/v1/84608/3.0', 49)]

# %%
for c in wapo.comments:
    if "" in c.message.lower():
        print(c)
# Out:
# 1:09:50.32         [MartinDoesStuff] - Alex Jones took a poly, they must be legit Kappa
# 1:51:13.85         [TheRealJonerzz] - @Diamond__Dick mitch jones mod PogChamp
# 4:52:58.93         [rikarie] - @PaulJones Alledgey Assaulted
# 5:38:02.17         [lootorshoottv] - @AbaddonTv you watching alot of alex jones lately
# 7:04:34.16         [amuseliese] - He gets Alex Jones face when he's upset. :/
# 8:49:03.62         [thapappas] - BROKEN RECORD JONES ResidentSleeper
# 9:32:40.31         [clambake420] - availJones
# 10:07:19.21        [clambake420] - availJones

# %%
bob = TwitchChat("data/313061370.json")

# %%
bob.plot_emoticons()

# %%
bob.plot_messages()

# %%
bob.commenters().most_common(30)
# Out:
# [('Tiamat37', 411),
#  ('letangier', 248),
#  ('twltchers', 211),
#  ('Moobot', 192),
#  ('chocosinok', 153),
#  ('Hemi_Dippin', 152),
#  ('nasgdt', 152),
#  ('theGrumpiestUnicorn', 141),
#  ('VaiaSilvers', 132),
#  ('vikatje', 121),
#  ('Eric__Tyler', 116),
#  ('Flappityflappyflap', 110),
#  ('DefStamina88', 109),
#  ('laike_ee_gluv', 103),
#  ('SUPERNlNTENDO', 101),
#  ('alfredmojoluna', 100),
#  ('blindn3ss', 100),
#  ('ricesan', 99),
#  ('Chrisby26', 96),
#  ('a_i_ngelic', 96),
#  ('Swoophy', 95),
#  ('Hizenkai', 90),
#  ('savvygreed', 90),
#  ('peeinmycheerios', 85),
#  ('Ayoken007', 82),
#  ('shrimpbeast', 82),
#  ('AJohnB', 80),
#  ('quarkstrudl', 80),
#  ('ccarnage86', 79),
#  ('MillaMallowBunny', 78)]

# %%
for c in bob.comments:
    if "trump" in c.message.lower():
        print(c)
# Out:
# 0:53:33.54         [yellowfreeze2014] - donald trumps hair
# 3:58:18.73         [newrubric] - Trump cloud
# 7:26:44.60         [jeremyracerperrin69] - Robert Bellow plays his cats like. Trumpet!
# 7:28:10.77         [jeremyracerperrin69] - Can bob paint a cat being played like a trumpet???
# 7:34:25.06         [jeremyracerperrin69] - Robert is playing his cat like a trumpet...Robert Bellow..
# 11:54:23.13        [Rapidsnapx] - I'm not a fan of any President or Prime Minster. I'm just a fan of whoever is managing their country better than anyone else in the world, and right now that just happens to be Donald Trump
# 12:02:46.99        [Tarsiz_] - i'm sorry to disappoint but trump has never built a wall with his hands, portuguese are much better at building walls
# 12:37:44.93        [Xayahis] - trump was a little happy accident
# 12:38:16.49        [saucydonut24] - trump just a accident
# 13:23:24.62        [Menjood] - trumpWow
# ...

# %%
for c in bob.comments:
    if c.commenter["name"] == "Tiamat37":
        print(c)
